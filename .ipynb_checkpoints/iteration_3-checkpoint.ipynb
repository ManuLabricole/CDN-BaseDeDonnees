# %%
import pandas as pd
import numpy as np
import sqlite3 as db
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pwd
# Out:
# '/Users/manulabricole/Documents/CDN/BDD'

# %%
colors = sns.color_palette('rocket', n_colors=12)
colors = sns.color_palette("tab10", n_colors=12)
colors = sns.color_palette("tab20_r", 16)
sns.palplot(colors)
sns.set_style("darkgrid")

# %% [markdown]
# --------

# %% [markdown]
# # C3 - S’interfacer avec Python

# %% [markdown]
# ---

# %% [markdown]
# # Import And Query

# %% [markdown]
# ### Name of the file .db

# %%
db_name = 'billboard-200.db'

# %% [markdown]
# ### Get infos of DB

# %%
def get_infos(db_file):
    conn = db.connect(db_file)
    cur = conn.cursor()
    
    # Retrieve the names of all tables in the database
    cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
    tables = [table[0] for table in cur.fetchall()]
    
    # Retrieve the columns in each table
    columns = {}
    for table in tables:
        cur.execute("PRAGMA table_info({})".format(table))
        columns[table] = [column[1] for column in cur.fetchall()]
    
    cur.close()
    conn.close()
    print("°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°")
    print("--------------- TABLES -----------------")
    print("")
    print("Tables:", tables)
    print("")
    print("--------------- COLUMNS ----------------")
    for table in tables:
        print("")
        print(f"----> {table} <----")
        print("Columns --> ", columns[table])

# %% [markdown]
# ### Query the DB

# %%
# The name has to be in the same folder as the notebook
def query_db(name, query):
    
    conn = db.connect(name)
    cur = conn.cursor()
    cur.execute(query)
    column_names = [description[0] for description in cur.description]
    results = cur.fetchall()
    cur.close()
    conn.close()
    
    df_results = pd.DataFrame(results, columns=column_names)

    return df_results

# %% [markdown]
# ### Test

# %%
query_db(db_name, "SELECT * FROM albums WHERE artist='The Beatles'")
# Out:
#           id        date       artist  \
# 0        118  2019-01-19  The Beatles
# 1        136  2019-01-19  The Beatles
# 2        139  2019-01-19  The Beatles
# 3        282  2019-01-12  The Beatles
# 4        327  2019-01-12  The Beatles
# ...      ...         ...          ...
# 2781  564970  1964-02-15  The Beatles
# 2782  565098  1964-02-15  The Beatles
# 2783  565104  1964-02-08  The Beatles
# 2784  565160  1964-02-08  The Beatles
# 2785  565352  1964-02-01  The Beatles
#
#                                                 album rank  length  \
# 0                           The Beatles [White Album]  117   107.0
# 1                                                   1  135    27.0
# 2                                          Abbey Road  138    17.0
# 3                           The Beatles [White Album]   81   107.0
# 4                                          Abbey Road  126    17.0
# ...                                               ...  ...     ...
# 2781                        Introducing...The Beatles   22     NaN
# 2782  The Beatles With Tony Sheridan And Their Guests  147     NaN
# 2783                                Meet The Beatles!    3    12.0
# 2784                        Introducing...The Beatles   59     NaN
# 2785                                Meet The Beatles!   92    12.0
#
#        track_length
# 0               NaN
# 1     172303.481481
# 2     184335.058824
# 3               NaN
# 4     184335.058824
# ...             ...
# 2781            NaN
# 2782            NaN
# 2783  209922.000000
# 2784            NaN
# 2785  209922.000000
#
# [2786 rows x 7 columns]

# %% [markdown]
# # billeboard-200

# %%
name = 'billboard-200.db'

# %%
get_infos(name)
# Out:
# °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°
# --------------- TABLES -----------------
#
# Tables: ['albums', 'acoustic_features']
#
# --------------- COLUMNS ----------------
#
# ----> albums <----
# Columns -->  ['id', 'date', 'artist', 'album', 'rank', 'length', 'track_length']
#
# ----> acoustic_features <----
# Columns -->  ['id', 'song', 'album', 'artist', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence', 'album_id', 'date']

# %%
query_db(name, "SELECT * from albums")
# Out:
#             id        date                    artist  \
# 0            1        None                      None
# 1            2  2019-01-19    A Boogie Wit da Hoodie
# 2            3  2019-01-19                 21 Savage
# 3            4  2019-01-19                Soundtrack
# 4            5  2019-01-19                 Meek Mill
# ...        ...         ...                       ...
# 573942  573943  1963-01-05  The Dave Brubeck Quartet
# 573943  573944  1963-01-05              Woody Herman
# 573944  573945  1963-01-05             Lawrence Welk
# 573945  573946  1963-01-05              Rusty Warren
# 573946  573947  1963-01-05             Stanley Black
#
#                                             album  rank  length   track_length
# 0                                            None  None     NaN            NaN
# 1                                      Hoodie SZN     1    20.0  185233.800000
# 2                                    I Am > I Was     2    15.0  211050.733333
# 3               Spider-Man: Into The Spider-Verse     3    13.0  190866.384615
# 4                                   Championships     4    19.0  219173.894737
# ...                                           ...   ...     ...            ...
# 573942  The Dave Brubeck Quartet At Carnegie Hall   146    12.0  527888.583333
# 573943                Encore: Woody Herman - 1963   147     NaN            NaN
# 573944                          1963's Early Hits   148     NaN            NaN
# 573945                               Knockers Up!   149     NaN            NaN
# 573946                           Film Spectacular   150     8.0  316766.375000
#
# [573947 rows x 7 columns]

# %% [markdown]
# ### Most week at number 1

# %%
query = "\
SELECT album, rank, COUNT(rank) AS count \
FROM albums \
WHERE (rank == 1 AND date > 1999)\
GROUP BY album \
ORDER BY count DESC \
LIMIT 10"

# %%
df = query_db(name, query)

# %%
df
# Out:
#           album rank  count
# 0            21    1     25
# 1         Views    1     13
# 2        Frozen    1     13
# 3  Supernatural    1     12
# 4      Fearless    1     11
# 5          1989    1     11
# 6    Millennium    1     10
# 7            25    1     10
# 8   Confessions    1      9
# 9     Weathered    1      8

# %% [markdown]
# ### Best album criteria

# %%
query = "\
SELECT artist, \
        album, \
        COUNT(rank) AS number_top_200, \
        SUM(rank) AS sum_classement,  \
        (AVG(rank)*1.0 / COUNT(rank)) AS score \
FROM albums \
GROUP BY album \
ORDER BY score ASC \
LIMIT 11"

# %%
df = query_db(name, query).dropna()

# %%
df
# Out:
#                               artist                          album  \
# 1    Tom Petty And The Heartbreakers                  Greatest Hits
# 2   Original Broadway Cast Recording  Hamilton: An American Musical
# 3                         Ed Sheeran                     ÷ (Divide)
# 4                        Post Malone                         Stoney
# 5                         Pink Floyd      The Dark Side Of The Moon
# 6                         Soundtrack             The Sound Of Music
# 7                        Post Malone           beerbongs & bentleys
# 8                       Shania Twain                   Come On Over
# 9                              Adele                             21
# 10                        Soundtrack           The Greatest Showman
#
#     number_top_200  sum_classement     score
# 1             5905        690596.0  0.019805
# 2              171          4027.0  0.137718
# 3               96          1298.0  0.140842
# 4              108          1674.0  0.143519
# 5              942        133356.0  0.150283
# 6              365         20279.0  0.152216
# 7               37           234.0  0.170928
# 8              175          5284.0  0.172539
# 9              412         31265.0  0.184189
# 10              56           584.0  0.186224

# %% [markdown]
# ------

# %% [markdown]
# # C4 - S’interfacer avec Pandas

# %% [markdown]
# -----

# %%
get_infos(name)
# Out:
# °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°
# --------------- TABLES -----------------
#
# Tables: ['albums', 'acoustic_features']
#
# --------------- COLUMNS ----------------
#
# ----> albums <----
# Columns -->  ['id', 'date', 'artist', 'album', 'rank', 'length', 'track_length']
#
# ----> acoustic_features <----
# Columns -->  ['id', 'song', 'album', 'artist', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence', 'album_id', 'date']

# %%
query = "\
SELECT id, song, album, artist, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence, album_id, date \
FROM acoustic_features \
"

# %%
df = query_db(name, query)

# %%
df = df.set_index("date");
df.index = pd.to_datetime(df.index)

# %% [markdown]
# ### Moyenne par année

# %%
df = df.resample("Y").mean().dropna()
df
# Out:
#             acousticness  danceability    duration_ms    energy  \
# date
# 1900-12-31      0.038448      0.363750  216361.166667  0.624083
# 1933-12-31      0.896780      0.687720  177955.000000  0.278340
# 1941-12-31      0.712571      0.456500  181861.000000  0.237207
# 1944-12-31      0.941444      0.331889  185583.722222  0.141528
# 1946-12-31      0.900937      0.523750  187104.625000  0.271750
# ...                  ...           ...            ...       ...
# 2015-12-31      0.266103      0.532740  235340.950129  0.641605
# 2016-12-31      0.280247      0.539637  233214.295504  0.630402
# 2017-12-31      0.275792      0.551348  223948.277797  0.630018
# 2018-12-31      0.282429      0.563352  220295.845046  0.615754
# 2019-12-31      0.401228      0.539803  220081.245675  0.539731
#
#             instrumentalness       key  liveness   loudness      mode  \
# date
# 1900-12-31          0.000373  6.416667  0.196208  -9.729333  0.666667
# 1933-12-31          0.018708  5.480000  0.197766 -11.930940  0.680000
# 1941-12-31          0.004762  3.714286  0.218300 -13.844214  0.714286
# 1944-12-31          0.024910  5.388889  0.300444 -17.104444  0.777778
# 1946-12-31          0.038312  4.937500  0.167525 -11.483688  0.937500
# ...                      ...       ...       ...        ...       ...
# 2015-12-31          0.115629  5.247882  0.229030  -8.017984  0.674107
# 2016-12-31          0.101624  5.213537  0.220787  -7.955032  0.675511
# 2017-12-31          0.107876  5.180572  0.217876  -7.919609  0.658986
# 2018-12-31          0.114322  5.218936  0.218786  -8.177894  0.654048
# 2019-12-31          0.162793  4.991349  0.238583 -10.703602  0.694637
#
#             speechiness       tempo  time_signature   valence
# date
# 1900-12-31     0.038833  133.889250        3.833333  0.389500
# 1933-12-31     0.059456  119.815680        3.980000  0.722960
# 1941-12-31     0.048771  104.562929        3.928571  0.361564
# 1944-12-31     0.045033  111.061167        3.555556  0.289772
# 1946-12-31     0.072556  112.294562        3.875000  0.576250
# ...                 ...         ...             ...       ...
# 2015-12-31     0.091737  120.651579        3.888619  0.441328
# 2016-12-31     0.095675  120.656077        3.873754  0.443337
# 2017-12-31     0.099882  120.301062        3.885301  0.440722
# 2018-12-31     0.111540  121.613524        3.901612  0.435543
# 2019-12-31     0.106815  119.330862        3.870242  0.456681
#
# [72 rows x 13 columns]

# %%
fig = plt.figure(figsize=(14, 6))
fig.suptitle("Acousticness evolution", fontsize=20)
sns.set_style("darkgrid")
ax = fig.subplots()

ax = sns.scatterplot(
    x=df.index, 
    y=df["acousticness"],
    color=colors[5],
    alpha=1,
    s=100,
    label="acousticness"
)
#ax = sns.lineplot(
#    x=df.index, 
#    y=df["loudness"],
#    color=colors[7], 
#    lw=3,
#    label="loudness"
#)
#ax = sns.lineplot(
#    x=x2, 
#    y=x2*slope2 + intercept2,
#    color=colors[9],
#    lw=3
#)

ax.set_xlabel("Années", loc="center", fontsize=15)
ax.set_ylabel("Acousticness", loc="center", fontsize=15)#, c=colors[color1])
fig.legend(loc=(0.83, 0.75))

# %%
fig = plt.figure(figsize=(14, 6))
fig.suptitle("Loudness evolution", fontsize=20)
sns.set_style("darkgrid")
ax = fig.subplots()

ax = sns.lineplot(
    x=df.index, 
    y=df["loudness"],
    color=colors[7], 
    lw=3,
    label="loudness"
)
#ax = sns.lineplot(
#    x=x2, 
#    y=x2*slope2 + intercept2,
#    color=colors[9],
#    lw=3
#)

ax.set_xlabel("Années", loc="center", fontsize=15)
ax.set_ylabel("Loudness", loc="center", fontsize=15)#, c=colors[color1])
fig.legend(loc=(0.83, 0.75))

# %%
fig = plt.figure(figsize=(14, 6))
fig.suptitle("speechiness evolution", fontsize=20)
sns.set_style("darkgrid")
ax = fig.subplots()

ax = sns.lineplot(
    x=df.index, 
    y=df["speechiness"],
    color=colors[9],
    lw=3
)

ax.set_xlabel("Années", loc="center", fontsize=15)
ax.set_ylabel("speechiness", loc="center", fontsize=15)#, c=colors[color1])
fig.legend(loc=(0.83, 0.75))
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# -----
